# %%
import pandas as pd

file = pd.read_csv('pokemon_data.csv')
file.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
file['Total'] = file['HP']+file['Attack']+file['Defense']+file['Sp. Atk']+file['Sp. Def'] +file['Speed']

file.loc[file['Total']>500,['Legendary','Generation']] = [True,round(file['Total']/100)]

file.head()
# Out:
# c:\Users\maison1\AppData\Local\Programs\Python\Python37-32\lib\site-packages\numpy\core\fromnumeric.py:3162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45         3.0      False    318
# ...

# %%
clmn = list(file.columns)


file= file[clmn[:4]+[clmn[-1]]+clmn[4:12]]
file.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45         3.0      False
# 1       80       80     60         4.0      False
# 2      100      100     80         5.0       True
# 3      122      120     80         6.0       True
# 4       60       50     65         3.0      False

# %%
file['Power'] = file['Attack'] - file['Defense']
file.head(5)

files= [files for files in file['Power']]




#file.loc[file['Total']>500,['Legendary','Generation']] = [True,round(file['Total']/100)]--> the concept i use its filtering
# the data and do what i want

file.loc[file['Power']>0 ,['MonsterType']] = 'Attacker'
file.loc[file['Power']<0 ,['MonsterType']] = 'Defenser'
file.loc[file['Power']== 0 ,['MonsterType']] = 'Normal'




file.head(5)

# its work
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Power MonsterType
# 0       65       65     45         3.0      False      0      Normal
# 1       80       80     60         4.0      False     -1    Defenser
# 2      100      100     80         5.0       True     -1    Defenser
# 3      122      120     80         6.0       True    -23    Defenser
# 4       60       50     65         3.0      False      9    Attacker

# %% [markdown]
# #all of thats not work so i will think for another solution without wifi :(
#         #if value >= 0:
#         #print(fils)
#           #  file['Monster Type'] = 'Attacker'
#
#        # elif value < 0 :
#         #    file['Monster Type'] = 'Defenser'

# %%
max(file['Speed'].sort_values())
# Out:
# 180

# %%
file.loc[file['Speed']== 180]
file['Generation'] =round(file['Total']/100)

print(file.columns[0])


file.loc[file['Speed']== 180]
# Out:
# #
#        #               Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 431  386  DeoxysSpeed Forme  Psychic    NaN    600  50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Power MonsterType
# 431       95       90    180         6.0       True      5    Attacker

# %%
file.to_excel('new_data_pokemon.xlsx',index=False)

# %%
defenser= file.loc[file['MonsterType']== 'Defenser'] 
attacker= file.loc[file['MonsterType']== 'Attacker'] 
normal= file.loc[file['MonsterType']== 'Normal']

# %%
import matplotlib.pyplot as plt


plt.plot(file['Power'],)
plt.show()

# %%
r= file['MonsterType'].value_counts()
atk=r.Attacker
deff= r.Defenser
nm= r.Normal
tl= [atk,deff,nm]
nms= ['attaks','defender','normal']
plt.bar(nms,tl)
plt.show()

# %%
file.to_excel('new_data_pokemon.xlsx',index=False)
